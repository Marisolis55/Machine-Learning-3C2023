# %% [markdown]
# <img src="banco1.jpg" alt="banco1">
#
# <h1 style = 'color:#14668a; text-align: center'>Universidad Castro Carazo</h1>
# <h3 style = 'color:#14668a; text-align: center'>Curso: Machine Learning</h3>
# <h3 style = 'color:#159a93; text-align: center'>Estudiante: Mariana Solis Roldan</h3>
# <h2 style = 'color:#7de0b9; text-align: center'>Proyecto Final</h2>

# %%
import pandas as pd 
#import nunpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %% [markdown]
# <h2 style="color: #f99200">Importacion del set de datos</h2>

# %%
credit = pd.read_excel("credit.xlsx")
credit.head(3)
# Out:
#    Unnamed: 0  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 0           0      20000  female  university         1   24      2      2
# 1           1     120000  female  university         2   26     -1      2
# 2           2      90000  female  university         2   34      0      0
#
#    PAY_3  PAY_4  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0     -1     -1  ...         0         0         0
# 1      0      0  ...      1000         0      2000
# 2      0      0  ...      1000      1000      5000
#
#    default payment next month(Y)  PAY 6  BILL AMTS  BILL AMT6  PAY AMT4  \
# 0                        default     -2          0          0         0
# 1                        default      2       3455       3261      1000
# 2                    not default      0      14948      15549      1000
#
#    PAY AMTS  PAY AMT6
# 0         0         0
# 1         0      2000
# 2      1000      5000
#
# [3 rows x 31 columns]

# %%
credit.drop(['Unnamed: 0'],axis=1,inplace=True)
credit.head(5)
# Out:
#    LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university         1   24      2      2     -1     -1
# 1     120000  female  university         2   26     -1      2      0      0
# 2      90000  female  university         2   34      0      0      0      0
# 3      50000  female  university         1   37      0      0      0      0
# 4      50000    male  university         1   57     -1      0     -1      0
#
#    PAY_5  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month(Y)  \
# 0     -2  ...         0         0         0                        default
# 1      0  ...      1000         0      2000                        default
# 2      0  ...      1000      1000      5000                    not default
# 3      0  ...      1100      1069      1000                    not default
# 4      0  ...      9000       689       679                    not default
#
# ...

# %% [markdown]
# <h2 style="color: #f99200">Visualizando los datos</h2>

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month(Y)', 'PAY 6', 'BILL AMTS', 'BILL AMT6',
#        'PAY AMT4', 'PAY AMTS', 'PAY AMT6'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 5))

#FORMATO DEL TITULO
title = "Grafico 1: Montos de creditos otorgados por frecuencia y por densidad"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.75,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "bold",
             fontfamily = "serif")

plt.subplot(1, 2, 1)
sns.histplot(credit['LIMIT_BAL'], bins=30, kde=True, color='skyblue')
plt.title('Histograma del Monto del Crédito Otorgado')
plt.xlabel('Monto del Crédito Otorgado')
plt.ylabel('Frecuencia')

plt.subplot(1, 2, 2)
sns.kdeplot(credit['LIMIT_BAL'], color='orange')
plt.title('Gráfico de Densidad del Monto del Crédito Otorgado')
plt.xlabel('Monto del Crédito Otorgado')
plt.ylabel('Densidad')

plt.tight_layout()
plt.show()

# %%
gender_counts = credit['SEX'].value_counts()
plt.figure(figsize=(7, 6))

#FORMATO DEL TITULO
title = "Grafico 2: Creditos otorgados por Genero"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.0001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "bold",
             fontfamily = "serif")
plt.bar(gender_counts.index, gender_counts.values, color='skyblue')
plt.title('Distribución de Género')
plt.xlabel('Género')
plt.ylabel('Cantidad')
plt.xticks(gender_counts.index, ['Masculino', 'Femenino'])  # Cambia las etiquetas del eje x si es necesario
plt.show()

# %%
education_counts = credit['EDUCATION'].value_counts()
plt.figure(figsize=(8, 6))

#FORMATO DEL TITULO
title = "Grafico 3: Creditos otorgados por Nivel Academico"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.0001,
             y = 0.69,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "bold",
             fontfamily = "serif")

#FORMATO DEL SUBTITULO
subTitle = "Distribución de Educación"  
ax.set_title(subTitle,
             horizontalalignment = 'left',
             x = 0.0007,
             y = 0.200,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")

plt.pie(education_counts.values, labels=education_counts.index, autopct='%1.1f%%', colors=['lightgreen', 'lightblue', 'lightcoral', 'lightskyblue', 'lightyellow'])
#plt.title('Distribución de Educación')

plt.show()
